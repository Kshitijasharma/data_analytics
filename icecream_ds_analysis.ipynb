# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\priya\Desktop\ANSHU\data analytic\icecream data set\talenti\products.csv")

# %%
df
# Out:
#            key                                   name  \
# 0    0_talenti                ALPHONSO MANGO SORBETTO
# 1    1_talenti                  BANANA CARAMEL CRUNCH
# 2    2_talenti               BELGIAN CHOCOLATE GELATO
# 3    3_talenti  BLACK RASPBERRY CHOCOLATE CHIP GELATO
# 4    4_talenti        BLACK RASPBERRY VANILLA PARFAIT
# 5    5_talenti               CARAMEL APPLE PIE GELATO
# 6    6_talenti           CARAMEL COOKIE CRUNCH GELATO
# 7    7_talenti               CARIBBEAN COCONUT GELATO
# 8    8_talenti            CHOCOLATE CHERRY CHEESECAKE
# 9    9_talenti     CHOCOLATE CHIP COOKIE DOUGH GELATO
# 10  10_talenti     CHOCOLATE PEANUT BUTTER CUP GELATO
# 11  11_talenti        COCONUT ALMOND CHOCOLATE GELATO
# 12  12_talenti               COCONUT CHOCOLATE COOKIE
# 13  13_talenti           COFFEE CHOCOLATE CHIP GELATO
# 14  14_talenti                  COFFEE COOKIE CRUMBLE
# 15  15_talenti              COLD BREW COFFEE SORBETTO
# ...

# %%
df.shape
# Out:
# (45, 6)

# %%
df.plot(title='Comparison',xlabel='Key',ylabel='Score')
# Out:
# <Axes: title={'center': 'Comparison'}, xlabel='Key', ylabel='Score'>

# %%
df.plot.scatter(x='rating',y='key')
# Out:
# <Axes: xlabel='rating', ylabel='key'>

# %%
df2=df.head(15)
df2.plot.scatter(x='rating',y='key')
# Out:
# <Axes: xlabel='rating', ylabel='key'>

# %%
df2.plot.scatter(x='rating',y='name')
# Out:
# <Axes: xlabel='rating', ylabel='name'>

# %%
df.plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize=(5,5))
# Out:
# <Axes: >

# %%
df.plot.pie(y='rating',subplots=True)
# Out:
# array([<Axes: ylabel='rating'>], dtype=object)

# %%
#filtering
df[df['rating']<3]
# Out:
#          key                                name  \
# 9  9_talenti  CHOCOLATE CHIP COOKIE DOUGH GELATO
#
#                                          description  rating  rating_count  \
# 9  We begin with our vanilla gelato, add chocolat...     2.8           104
#
#                                          ingredients
# 9  MILK, SUGAR, CREAM, WHEAT FLOUR, DEXTROSE, SKI...

# %%
df[df['rating']>=4]
# Out:
#            key                                   name  \
# 0    0_talenti                ALPHONSO MANGO SORBETTO
# 1    1_talenti                  BANANA CARAMEL CRUNCH
# 2    2_talenti               BELGIAN CHOCOLATE GELATO
# 3    3_talenti  BLACK RASPBERRY CHOCOLATE CHIP GELATO
# 4    4_talenti        BLACK RASPBERRY VANILLA PARFAIT
# 5    5_talenti               CARAMEL APPLE PIE GELATO
# 6    6_talenti           CARAMEL COOKIE CRUNCH GELATO
# 7    7_talenti               CARIBBEAN COCONUT GELATO
# 8    8_talenti            CHOCOLATE CHERRY CHEESECAKE
# 10  10_talenti     CHOCOLATE PEANUT BUTTER CUP GELATO
# 11  11_talenti        COCONUT ALMOND CHOCOLATE GELATO
# 12  12_talenti               COCONUT CHOCOLATE COOKIE
# 13  13_talenti           COFFEE CHOCOLATE CHIP GELATO
# 14  14_talenti                  COFFEE COOKIE CRUMBLE
# 15  15_talenti              COLD BREW COFFEE SORBETTO
# 16  16_talenti                  DARK CHOCOLATE CHERRY
# ...

# %%
df[df['name'].str.contains('CHOCOLATE')]  #chocolate flavored
# Out:
#            key                                   name  \
# 2    2_talenti               BELGIAN CHOCOLATE GELATO
# 3    3_talenti  BLACK RASPBERRY CHOCOLATE CHIP GELATO
# 8    8_talenti            CHOCOLATE CHERRY CHEESECAKE
# 9    9_talenti     CHOCOLATE CHIP COOKIE DOUGH GELATO
# 10  10_talenti     CHOCOLATE PEANUT BUTTER CUP GELATO
# 11  11_talenti        COCONUT ALMOND CHOCOLATE GELATO
# 12  12_talenti               COCONUT CHOCOLATE COOKIE
# 13  13_talenti           COFFEE CHOCOLATE CHIP GELATO
# 16  16_talenti                  DARK CHOCOLATE CHERRY
# 17  17_talenti                DARK CHOCOLATE SORBETTO
# 18  18_talenti           DOUBLE DARK CHOCOLATE GELATO
# 20  20_talenti         HAZELNUT CHOCOLATE CHIP GELATO
# 28  28_talenti        ORGANIC CHOCOLATE MOUSSE GELATO
#
#                                           description  rating  rating_count  \
# 2   Our Belgian Chocolate gelato is made with melt...     4.8            27
# ...

# %%
df.iloc[15]
# Out:
# key                                                    15_talenti
# name                                    COLD BREW COFFEE SORBETTO
# description     Our Cold Brew Coffee Sorbetto is created by pe...
# rating                                                        4.5
# rating_count                                                  131
# ingredients     WATER, SUGAR, EGG YOLKS AND EGG WHITES, COCONU...
# Name: 15, dtype: object
